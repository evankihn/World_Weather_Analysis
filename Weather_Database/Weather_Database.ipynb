# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5405c6386e6bb183da0067ca1b818bef

# %%
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country})


# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | honiara
# Processing Record 4 of Set 1 | agutaya
# Processing Record 5 of Set 1 | kavieng
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | port macquarie
# Processing Record 9 of Set 1 | andenes
# Processing Record 10 of Set 1 | itarema
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | tabora
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | alofi
# Processing Record 16 of Set 1 | tilichiki
# Processing Record 17 of Set 1 | sao luis
# Processing Record 18 of Set 1 | bababe
# City not found. Skipping...
# Processing Record 19 of Set 1 | aksarka
# Processing Record 20 of Set 1 | carnarvon
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | port hardy
# Processing Record 25 of Set 1 | hovd
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | bredasdorp
# Processing Record 28 of Set 1 | santa maria
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 1 | kapaa
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | lapy
# Processing Record 35 of Set 1 | saldanha
# Processing Record 36 of Set 1 | punta cardon
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | nikolskoye
# Processing Record 39 of Set 1 | ponta do sol
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | matsanga
# City not found. Skipping...
# Processing Record 42 of Set 1 | mareeba
# Processing Record 43 of Set 1 | iqaluit
# Processing Record 44 of Set 1 | daitari
# Processing Record 45 of Set 1 | lagoa
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | baishishan
# Processing Record 48 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 1 | usinsk
# Processing Record 50 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 2 | mandera
# Processing Record 2 of Set 2 | santa cecilia
# Processing Record 3 of Set 2 | norman wells
# Processing Record 4 of Set 2 | mehamn
# Processing Record 5 of Set 2 | taoudenni
# Processing Record 6 of Set 2 | dharchula
# Processing Record 7 of Set 2 | yulara
# Processing Record 8 of Set 2 | ancud
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | saint-philippe
# Processing Record 11 of Set 2 | gornopravdinsk
# Processing Record 12 of Set 2 | verkhnevilyuysk
# Processing Record 13 of Set 2 | valera
# Processing Record 14 of Set 2 | kassala
# Processing Record 15 of Set 2 | lebu
# Processing Record 16 of Set 2 | lorengau
# Processing Record 17 of Set 2 | namibe
# Processing Record 18 of Set 2 | masvingo
# Processing Record 19 of Set 2 | esperance
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 22 of Set 2 | the valley
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | weligama
# Processing Record 25 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 2 | clyde river
# Processing Record 27 of Set 2 | rikitea
# Processing Record 28 of Set 2 | yellowknife
# Processing Record 29 of Set 2 | mayo
# Processing Record 30 of Set 2 | ribeira grande
# Processing Record 31 of Set 2 | juruti
# Processing Record 32 of Set 2 | kieta
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 | arima
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | hervey bay
# Processing Record 37 of Set 2 | punta arenas
# Processing Record 38 of Set 2 | isangel
# Processing Record 39 of Set 2 | pevek
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | mancora
# Processing Record 44 of Set 2 | mogok
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | bowen
# Processing Record 47 of Set 2 | whitianga
# Processing Record 48 of Set 2 | berlevag
# Processing Record 49 of Set 2 | avarua
# Processing Record 50 of Set 2 | altay
# Processing Record 1 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 3 | lebork
# Processing Record 3 of Set 3 | brae
# Processing Record 4 of Set 3 | mount gambier
# Processing Record 5 of Set 3 | dalvik
# Processing Record 6 of Set 3 | flinders
# Processing Record 7 of Set 3 | shimoda
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | villa de cura
# Processing Record 10 of Set 3 | zhigansk
# Processing Record 11 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 3 | los llanos de aridane
# Processing Record 13 of Set 3 | port-cartier
# Processing Record 14 of Set 3 | saint george
# Processing Record 15 of Set 3 | castrillon
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | cabo san lucas
# Processing Record 18 of Set 3 | sabang
# Processing Record 19 of Set 3 | ninghai
# Processing Record 20 of Set 3 | half moon bay
# Processing Record 21 of Set 3 | kaitangata
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | nador
# Processing Record 24 of Set 3 | new norfolk
# Processing Record 25 of Set 3 | tasiilaq
# Processing Record 26 of Set 3 | san quintin
# Processing Record 27 of Set 3 | aksu
# Processing Record 28 of Set 3 | kamenka
# Processing Record 29 of Set 3 | baykit
# Processing Record 30 of Set 3 | lufilufi
# Processing Record 31 of Set 3 | bambous virieux
# Processing Record 32 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 3 | san clemente
# Processing Record 34 of Set 3 | butaritari
# Processing Record 35 of Set 3 | port lincoln
# Processing Record 36 of Set 3 | olafsvik
# Processing Record 37 of Set 3 | guerrero negro
# Processing Record 38 of Set 3 | mekhe
# Processing Record 39 of Set 3 | jining
# Processing Record 40 of Set 3 | nelson bay
# Processing Record 41 of Set 3 | sangmelima
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | ordu
# Processing Record 44 of Set 3 | bardiyah
# Processing Record 45 of Set 3 | krasnoshchekovo
# Processing Record 46 of Set 3 | berdyuzhye
# City not found. Skipping...
# Processing Record 47 of Set 3 | nurota
# Processing Record 48 of Set 3 | belyy yar
# Processing Record 49 of Set 3 | tucurui
# Processing Record 50 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 4 | lady frere
# Processing Record 2 of Set 4 | silvan
# Processing Record 3 of Set 4 | kachiry
# Processing Record 4 of Set 4 | hirara
# Processing Record 5 of Set 4 | mastung
# Processing Record 6 of Set 4 | port alfred
# Processing Record 7 of Set 4 | tiksi
# Processing Record 8 of Set 4 | phan thiet
# Processing Record 9 of Set 4 | merauke
# Processing Record 10 of Set 4 | sisimiut
# Processing Record 11 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 4 | vardo
# Processing Record 13 of Set 4 | kahramanmaras
# Processing Record 14 of Set 4 | qaanaaq
# Processing Record 15 of Set 4 | goderich
# Processing Record 16 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 4 | dingle
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | axim
# Processing Record 20 of Set 4 | necochea
# Processing Record 21 of Set 4 | salalah
# Processing Record 22 of Set 4 | roald
# Processing Record 23 of Set 4 | muncar
# Processing Record 24 of Set 4 | camopi
# Processing Record 25 of Set 4 | santa fe
# Processing Record 26 of Set 4 | fort-shevchenko
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | mitsamiouli
# Processing Record 29 of Set 4 | dolores
# Processing Record 30 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 4 | emmaus
# Processing Record 32 of Set 4 | hobyo
# Processing Record 33 of Set 4 | vila franca do campo
# Processing Record 34 of Set 4 | freiberg
# Processing Record 35 of Set 4 | sao filipe
# Processing Record 36 of Set 4 | katsuura
# Processing Record 37 of Set 4 | mandurah
# Processing Record 38 of Set 4 | tianpeng
# Processing Record 39 of Set 4 | athabasca
# Processing Record 40 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 42 of Set 4 | sitka
# Processing Record 43 of Set 4 | lompoc
# Processing Record 44 of Set 4 | komono
# Processing Record 45 of Set 4 | teknaf
# Processing Record 46 of Set 4 | balkanabat
# Processing Record 47 of Set 4 | dudinka
# Processing Record 48 of Set 4 | jurado
# Processing Record 49 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 4 | angoram
# Processing Record 1 of Set 5 | brownsburg
# Processing Record 2 of Set 5 | batagay-alyta
# Processing Record 3 of Set 5 | san patricio
# Processing Record 4 of Set 5 | kurduvadi
# Processing Record 5 of Set 5 | colchester
# Processing Record 6 of Set 5 | ukiah
# Processing Record 7 of Set 5 | trat
# Processing Record 8 of Set 5 | shingu
# Processing Record 9 of Set 5 | el vigia
# Processing Record 10 of Set 5 | ketchikan
# Processing Record 11 of Set 5 | faya
# Processing Record 12 of Set 5 | constitucion
# Processing Record 13 of Set 5 | buta
# Processing Record 14 of Set 5 | colmenar viejo
# Processing Record 15 of Set 5 | maragogi
# Processing Record 16 of Set 5 | nicolas bravo
# Processing Record 17 of Set 5 | hofn
# Processing Record 18 of Set 5 | niquelandia
# Processing Record 19 of Set 5 | juegang
# Processing Record 20 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 21 of Set 5 | quimper
# Processing Record 22 of Set 5 | geraldton
# Processing Record 23 of Set 5 | erdenet
# Processing Record 24 of Set 5 | riyadh
# Processing Record 25 of Set 5 | abatskoye
# Processing Record 26 of Set 5 | mackay
# Processing Record 27 of Set 5 | kaitong
# Processing Record 28 of Set 5 | clinton
# Processing Record 29 of Set 5 | atar
# Processing Record 30 of Set 5 | sao joao da barra
# Processing Record 31 of Set 5 | sept-iles
# Processing Record 32 of Set 5 | dikson
# Processing Record 33 of Set 5 | teya
# Processing Record 34 of Set 5 | naliya
# Processing Record 35 of Set 5 | luderitz
# Processing Record 36 of Set 5 | flin flon
# Processing Record 37 of Set 5 | tuatapere
# Processing Record 38 of Set 5 | ilulissat
# Processing Record 39 of Set 5 | scarborough
# Processing Record 40 of Set 5 | yanam
# Processing Record 41 of Set 5 | arakhnaion
# City not found. Skipping...
# Processing Record 42 of Set 5 | darovskoy
# Processing Record 43 of Set 5 | kruisfontein
# Processing Record 44 of Set 5 | torbay
# Processing Record 45 of Set 5 | galeana
# Processing Record 46 of Set 5 | khatanga
# Processing Record 47 of Set 5 | chokurdakh
# Processing Record 48 of Set 5 | narsaq
# Processing Record 49 of Set 5 | pochutla
# Processing Record 50 of Set 5 | waingapu
# Processing Record 1 of Set 6 | naryan-mar
# Processing Record 2 of Set 6 | leningradskiy
# Processing Record 3 of Set 6 | nogliki
# Processing Record 4 of Set 6 | gaya
# Processing Record 5 of Set 6 | bairiki
# Processing Record 6 of Set 6 | ginda
# Processing Record 7 of Set 6 | mercedes
# Processing Record 8 of Set 6 | chikoy
# City not found. Skipping...
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | samarai
# Processing Record 11 of Set 6 | presidencia roque saenz pena
# Processing Record 12 of Set 6 | suksun
# Processing Record 13 of Set 6 | hithadhoo
# Processing Record 14 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 6 | upernavik
# Processing Record 16 of Set 6 | pisco
# Processing Record 17 of Set 6 | tuy hoa
# Processing Record 18 of Set 6 | mineiros
# Processing Record 19 of Set 6 | ampanihy
# Processing Record 20 of Set 6 | kaseda
# Processing Record 21 of Set 6 | puerto colombia
# Processing Record 22 of Set 6 | nhulunbuy
# Processing Record 23 of Set 6 | adrar
# Processing Record 24 of Set 6 | codrington
# Processing Record 25 of Set 6 | muisne
# Processing Record 26 of Set 6 | port moresby
# Processing Record 27 of Set 6 | karratha
# Processing Record 28 of Set 6 | margate
# Processing Record 29 of Set 6 | bilibino
# Processing Record 30 of Set 6 | saint anthony
# Processing Record 31 of Set 6 | ekhinos
# Processing Record 32 of Set 6 | bandarbeyla
# Processing Record 33 of Set 6 | katha
# City not found. Skipping...
# Processing Record 34 of Set 6 | kurud
# Processing Record 35 of Set 6 | bay roberts
# Processing Record 36 of Set 6 | port blair
# Processing Record 37 of Set 6 | manga
# Processing Record 38 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 39 of Set 6 | fairbanks
# Processing Record 40 of Set 6 | aquiraz
# Processing Record 41 of Set 6 | russell
# Processing Record 42 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 6 | souillac
# Processing Record 44 of Set 6 | avera
# Processing Record 45 of Set 6 | port-gentil
# Processing Record 46 of Set 6 | alto baudo
# City not found. Skipping...
# Processing Record 47 of Set 6 | aripuana
# Processing Record 48 of Set 6 | port hedland
# Processing Record 49 of Set 6 | les cayes
# Processing Record 50 of Set 6 | pangkalanbuun
# Processing Record 1 of Set 7 | saint helens
# Processing Record 2 of Set 7 | hun
# Processing Record 3 of Set 7 | marsaxlokk
# Processing Record 4 of Set 7 | carnot
# Processing Record 5 of Set 7 | belmonte
# Processing Record 6 of Set 7 | dicabisagan
# Processing Record 7 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 8 of Set 7 | rio gallegos
# Processing Record 9 of Set 7 | katangli
# Processing Record 10 of Set 7 | te anau
# Processing Record 11 of Set 7 | ust-kulom
# Processing Record 12 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 7 | laguna
# Processing Record 14 of Set 7 | lopatyn
# Processing Record 15 of Set 7 | bethel
# Processing Record 16 of Set 7 | forbes
# Processing Record 17 of Set 7 | zarubino
# Processing Record 18 of Set 7 | provideniya
# Processing Record 19 of Set 7 | strezhevoy
# Processing Record 20 of Set 7 | senneterre
# Processing Record 21 of Set 7 | magui
# City not found. Skipping...
# Processing Record 22 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 7 | hasaki
# Processing Record 24 of Set 7 | bambanglipuro
# Processing Record 25 of Set 7 | farafangana
# Processing Record 26 of Set 7 | yermakovskoye
# Processing Record 27 of Set 7 | tacna
# Processing Record 28 of Set 7 | kuala terengganu
# Processing Record 29 of Set 7 | tabou
# Processing Record 30 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 31 of Set 7 | dombarovskiy
# Processing Record 32 of Set 7 | lucapa
# Processing Record 33 of Set 7 | asfi
# Processing Record 34 of Set 7 | kaeo
# Processing Record 35 of Set 7 | cherskiy
# Processing Record 36 of Set 7 | chapais
# Processing Record 37 of Set 7 | progreso
# Processing Record 38 of Set 7 | puerto escondido
# Processing Record 39 of Set 7 | sola
# Processing Record 40 of Set 7 | touros
# Processing Record 41 of Set 7 | kifri
# Processing Record 42 of Set 7 | nantucket
# Processing Record 43 of Set 7 | lasa
# Processing Record 44 of Set 7 | kichera
# Processing Record 45 of Set 7 | bathsheba
# Processing Record 46 of Set 7 | aalen
# Processing Record 47 of Set 7 | kayerkan
# Processing Record 48 of Set 7 | caravelas
# Processing Record 49 of Set 7 | lavrentiya
# Processing Record 50 of Set 7 | fort nelson
# Processing Record 1 of Set 8 | la ronge
# Processing Record 2 of Set 8 | cananeia
# Processing Record 3 of Set 8 | gorontalo
# Processing Record 4 of Set 8 | gannan
# Processing Record 5 of Set 8 | tyup
# Processing Record 6 of Set 8 | havre-saint-pierre
# Processing Record 7 of Set 8 | tanete
# Processing Record 8 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 8 | port elizabeth
# Processing Record 10 of Set 8 | grindavik
# Processing Record 11 of Set 8 | broome
# Processing Record 12 of Set 8 | derzhavinsk
# Processing Record 13 of Set 8 | igdir
# Processing Record 14 of Set 8 | salvador
# Processing Record 15 of Set 8 | tadine
# Processing Record 16 of Set 8 | yaan
# Processing Record 17 of Set 8 | choya
# Processing Record 18 of Set 8 | vostok
# Processing Record 19 of Set 8 | saint-leu
# Processing Record 20 of Set 8 | camana
# Processing Record 21 of Set 8 | taksimo
# Processing Record 22 of Set 8 | borba
# Processing Record 23 of Set 8 | male
# Processing Record 24 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 25 of Set 8 | termoli
# Processing Record 26 of Set 8 | srednekolymsk
# Processing Record 27 of Set 8 | araguaina
# Processing Record 28 of Set 8 | vila velha
# Processing Record 29 of Set 8 | cabedelo
# Processing Record 30 of Set 8 | turangi
# Processing Record 31 of Set 8 | buala
# Processing Record 32 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 33 of Set 8 | pokhara
# Processing Record 34 of Set 8 | aklavik
# Processing Record 35 of Set 8 | san carlos de bariloche
# Processing Record 36 of Set 8 | guane
# Processing Record 37 of Set 8 | zolotinka
# City not found. Skipping...
# Processing Record 38 of Set 8 | okha
# Processing Record 39 of Set 8 | midland
# Processing Record 40 of Set 8 | oranjemund
# Processing Record 41 of Set 8 | saskylakh
# Processing Record 42 of Set 8 | osypenko
# Processing Record 43 of Set 8 | verkhniye tatyshly
# Processing Record 44 of Set 8 | tulu bolo
# Processing Record 45 of Set 8 | beringovskiy
# Processing Record 46 of Set 8 | ixtapa
# Processing Record 47 of Set 8 | roros
# Processing Record 48 of Set 8 | rio grande
# Processing Record 49 of Set 8 | saint-pierre
# Processing Record 50 of Set 8 | bethanien
# Processing Record 1 of Set 9 | kambove
# Processing Record 2 of Set 9 | aswan
# Processing Record 3 of Set 9 | presidente medici
# Processing Record 4 of Set 9 | novikovo
# Processing Record 5 of Set 9 | auki
# Processing Record 6 of Set 9 | coquimbo
# Processing Record 7 of Set 9 | lukow
# Processing Record 8 of Set 9 | marawi
# Processing Record 9 of Set 9 | hokitika
# Processing Record 10 of Set 9 | bonoua
# Processing Record 11 of Set 9 | the village
# Processing Record 12 of Set 9 | longkou
# Processing Record 13 of Set 9 | kovdor
# Processing Record 14 of Set 9 | erzin
# Processing Record 15 of Set 9 | ise
# Processing Record 16 of Set 9 | bousso
# Processing Record 17 of Set 9 | sergeyevka
# Processing Record 18 of Set 9 | hualmay
# Processing Record 19 of Set 9 | port keats
# Processing Record 20 of Set 9 | puteyets
# Processing Record 21 of Set 9 | padang
# Processing Record 22 of Set 9 | gilbues
# Processing Record 23 of Set 9 | sidi ali
# Processing Record 24 of Set 9 | ngunguru
# Processing Record 25 of Set 9 | bang mun nak
# Processing Record 26 of Set 9 | kibala
# Processing Record 27 of Set 9 | kloulklubed
# Processing Record 28 of Set 9 | poum
# Processing Record 29 of Set 9 | guaruja
# Processing Record 30 of Set 9 | fukue
# Processing Record 31 of Set 9 | omboue
# Processing Record 32 of Set 9 | acari
# Processing Record 33 of Set 9 | pacific grove
# Processing Record 34 of Set 9 | pietarsaari
# Processing Record 35 of Set 9 | mykhaylivka
# Processing Record 36 of Set 9 | college
# Processing Record 37 of Set 9 | matamoros
# Processing Record 38 of Set 9 | harper
# Processing Record 39 of Set 9 | pafos
# Processing Record 40 of Set 9 | maniitsoq
# Processing Record 41 of Set 9 | buchanan
# Processing Record 42 of Set 9 | roebourne
# Processing Record 43 of Set 9 | changji
# Processing Record 44 of Set 9 | ca mau
# Processing Record 45 of Set 9 | longyearbyen
# Processing Record 46 of Set 9 | marsa matruh
# Processing Record 47 of Set 9 | bahia blanca
# Processing Record 48 of Set 9 | saint-augustin
# Processing Record 49 of Set 9 | sabha
# Processing Record 50 of Set 9 | tomigusuku
# Processing Record 1 of Set 10 | letnyaya stavka
# Processing Record 2 of Set 10 | sabla
# Processing Record 3 of Set 10 | anadyr
# Processing Record 4 of Set 10 | portland
# Processing Record 5 of Set 10 | tarko-sale
# Processing Record 6 of Set 10 | paamiut
# Processing Record 7 of Set 10 | chizhou
# Processing Record 8 of Set 10 | makakilo city
# Processing Record 9 of Set 10 | buraydah
# Processing Record 10 of Set 10 | kontagora
# Processing Record 11 of Set 10 | yazman
# Processing Record 12 of Set 10 | brunswick
# Processing Record 13 of Set 10 | jimma
# Processing Record 14 of Set 10 | yumen
# Processing Record 15 of Set 10 | plouzane
# Processing Record 16 of Set 10 | kalmunai
# Processing Record 17 of Set 10 | gadarwara
# Processing Record 18 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 10 | grajau
# Processing Record 20 of Set 10 | cheyenne
# Processing Record 21 of Set 10 | clifton
# Processing Record 22 of Set 10 | verkhoyansk
# Processing Record 23 of Set 10 | vao
# Processing Record 24 of Set 10 | mahajanga
# Processing Record 25 of Set 10 | belaya gora
# Processing Record 26 of Set 10 | malatya
# Processing Record 27 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 10 | juterbog
# Processing Record 29 of Set 10 | bichura
# Processing Record 30 of Set 10 | tynda
# Processing Record 31 of Set 10 | bata
# Processing Record 32 of Set 10 | khash
# Processing Record 33 of Set 10 | thouars
# Processing Record 34 of Set 10 | alice springs
# Processing Record 35 of Set 10 | zheleznogorsk
# Processing Record 36 of Set 10 | san cristobal
# Processing Record 37 of Set 10 | virginia beach
# Processing Record 38 of Set 10 | muscatine
# Processing Record 39 of Set 10 | nanortalik
# Processing Record 40 of Set 10 | ostrovnoy
# Processing Record 41 of Set 10 | soure
# Processing Record 42 of Set 10 | sri aman
# Processing Record 43 of Set 10 | newark
# Processing Record 44 of Set 10 | yar-sale
# Processing Record 45 of Set 10 | shaunavon
# Processing Record 46 of Set 10 | peleduy
# Processing Record 47 of Set 10 | oktyabrskiy
# Processing Record 48 of Set 10 | takoradi
# Processing Record 49 of Set 10 | urulga
# City not found. Skipping...
# Processing Record 50 of Set 10 | khudumelapye
# Processing Record 1 of Set 11 | zandvoort
# Processing Record 2 of Set 11 | ust-ilimsk
# Processing Record 3 of Set 11 | qinggang
# Processing Record 4 of Set 11 | venado tuerto
# Processing Record 5 of Set 11 | saint-paul
# Processing Record 6 of Set 11 | hearst
# Processing Record 7 of Set 11 | saint-denis
# Processing Record 8 of Set 11 | gwadar
# Processing Record 9 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 11 | lewiston
# Processing Record 11 of Set 11 | santa ines
# Processing Record 12 of Set 11 | faanui
# Processing Record 13 of Set 11 | sistranda
# Processing Record 14 of Set 11 | jurm
# Processing Record 15 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 11 | krasnokholmskiy
# Processing Record 17 of Set 11 | kang
# Processing Record 18 of Set 11 | correntina
# Processing Record 19 of Set 11 | saint-felicien
# Processing Record 20 of Set 11 | jomalig
# City not found. Skipping...
# Processing Record 21 of Set 11 | zabol
# Processing Record 22 of Set 11 | kapoeta
# Processing Record 23 of Set 11 | gornyak
# Processing Record 24 of Set 11 | savannah bight
# Processing Record 25 of Set 11 | pangnirtung
# Processing Record 26 of Set 11 | waw
# Processing Record 27 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 11 | bonthe
# Processing Record 29 of Set 11 | ballina
# Processing Record 30 of Set 11 | acajutla
# Processing Record 31 of Set 11 | vitim
# Processing Record 32 of Set 11 | brownsville
# Processing Record 33 of Set 11 | tarnos
# Processing Record 34 of Set 11 | bonito
# Processing Record 35 of Set 11 | kavaratti
# Processing Record 36 of Set 11 | marathon
# Processing Record 37 of Set 11 | nsanje
# Processing Record 38 of Set 11 | paraguacu
# Processing Record 39 of Set 11 | vestmannaeyjar
# Processing Record 40 of Set 11 | tonekabon
# Processing Record 41 of Set 11 | zhangye
# Processing Record 42 of Set 11 | nara
# Processing Record 43 of Set 11 | abu dhabi
# Processing Record 44 of Set 11 | bengkulu
# Processing Record 45 of Set 11 | canakkale
# Processing Record 46 of Set 11 | grand-santi
# Processing Record 47 of Set 11 | palasa
# Processing Record 48 of Set 11 | north bend
# Processing Record 49 of Set 11 | hoshangabad
# Processing Record 50 of Set 11 | tatawin
# Processing Record 1 of Set 12 | najran
# Processing Record 2 of Set 12 | hay river
# Processing Record 3 of Set 12 | hope
# Processing Record 4 of Set 12 | kano
# Processing Record 5 of Set 12 | williams lake
# Processing Record 6 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 12 | namatanai
# Processing Record 8 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 9 of Set 12 | nizwa
# Processing Record 10 of Set 12 | eyl
# Processing Record 11 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 12 | ola
# Processing Record 13 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 12 | kiunga
# Processing Record 15 of Set 12 | levelland
# Processing Record 16 of Set 12 | mathbaria
# Processing Record 17 of Set 12 | ortigueira
# Processing Record 18 of Set 12 | metro
# Processing Record 19 of Set 12 | parung
# Processing Record 20 of Set 12 | svetlogorsk
# Processing Record 21 of Set 12 | asau
# Processing Record 22 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 23 of Set 12 | kikwit
# Processing Record 24 of Set 12 | wah
# Processing Record 25 of Set 12 | horsham
# Processing Record 26 of Set 12 | chokwe
# Processing Record 27 of Set 12 | ovalle
# Processing Record 28 of Set 12 | cap malheureux
# Processing Record 29 of Set 12 | yeppoon
# Processing Record 30 of Set 12 | ordynskoye
# Processing Record 31 of Set 12 | port arthur
# Processing Record 32 of Set 12 | mungwi
# Processing Record 33 of Set 12 | durango
# Processing Record 34 of Set 12 | bor
# Processing Record 35 of Set 12 | martapura
# Processing Record 36 of Set 12 | tucuman
# Processing Record 37 of Set 12 | toyooka
# Processing Record 38 of Set 12 | sioux lookout
# Processing Record 39 of Set 12 | ochakiv
# Processing Record 40 of Set 12 | qandala
# Processing Record 41 of Set 12 | arkhangelos
# City not found. Skipping...
# Processing Record 42 of Set 12 | champerico
# Processing Record 43 of Set 12 | kysyl-syr
# Processing Record 44 of Set 12 | mildura
# Processing Record 45 of Set 12 | shubarshi
# Processing Record 46 of Set 12 | sinnamary
# Processing Record 47 of Set 12 | greenwood
# Processing Record 48 of Set 12 | staritsa
# Processing Record 49 of Set 12 | gat
# Processing Record 50 of Set 12 | baglung
# Processing Record 1 of Set 13 | evensk
# Processing Record 2 of Set 13 | ugoofaaru
# Processing Record 3 of Set 13 | amalapuram
# Processing Record 4 of Set 13 | klaksvik
# Processing Record 5 of Set 13 | haines junction
# Processing Record 6 of Set 13 | key west
# Processing Record 7 of Set 13 | inuvik
# Processing Record 8 of Set 13 | bubaque
# Processing Record 9 of Set 13 | uvalde
# Processing Record 10 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 11 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 12 of Set 13 | ardesen
# Processing Record 13 of Set 13 | tautira
# Processing Record 14 of Set 13 | aranos
# Processing Record 15 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 16 of Set 13 | luganville
# Processing Record 17 of Set 13 | shushtar
# Processing Record 18 of Set 13 | beloha
# Processing Record 19 of Set 13 | lethem
# Processing Record 20 of Set 13 | kerouane
# Processing Record 21 of Set 13 | aguas vermelhas
# Processing Record 22 of Set 13 | bang saphan
# Processing Record 23 of Set 13 | dunedin
# Processing Record 24 of Set 13 | douentza
# Processing Record 25 of Set 13 | oranmore
# Processing Record 26 of Set 13 | yuryevets
# Processing Record 27 of Set 13 | vila
# Processing Record 28 of Set 13 | dhidhdhoo
# Processing Record 29 of Set 13 | vangaindrano
# Processing Record 30 of Set 13 | santo antonio do taua
# Processing Record 31 of Set 13 | kabo
# Processing Record 32 of Set 13 | kondinskoye
# Processing Record 33 of Set 13 | santa cruz de tenerife
# Processing Record 34 of Set 13 | solton
# Processing Record 35 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 36 of Set 13 | sao francisco do sul
# Processing Record 37 of Set 13 | vanimo
# Processing Record 38 of Set 13 | xam nua
# Processing Record 39 of Set 13 | bongandanga
# Processing Record 40 of Set 13 | banda aceh
# Processing Record 41 of Set 13 | iwaki
# Processing Record 42 of Set 13 | tall kayf
# Processing Record 43 of Set 13 | anito
# Processing Record 44 of Set 13 | gobabis
# Processing Record 45 of Set 13 | akdepe
# Processing Record 46 of Set 13 | la romana
# Processing Record 47 of Set 13 | elbistan
# Processing Record 48 of Set 13 | devonport
# Processing Record 49 of Set 13 | mount isa
# Processing Record 50 of Set 13 | moreno valley
# Processing Record 1 of Set 14 | bolshaya sosnova
# Processing Record 2 of Set 14 | cao bang
# Processing Record 3 of Set 14 | betanzos
# Processing Record 4 of Set 14 | coos bay
# Processing Record 5 of Set 14 | perevoz
# Processing Record 6 of Set 14 | homer
# Processing Record 7 of Set 14 | nouadhibou
# Processing Record 8 of Set 14 | huarmey
# Processing Record 9 of Set 14 | ust-ishim
# Processing Record 10 of Set 14 | xuddur
# Processing Record 11 of Set 14 | pimenta bueno
# Processing Record 12 of Set 14 | preobrazheniye
# Processing Record 13 of Set 14 | tamiahua
# Processing Record 14 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 14 | novyy urengoy
# Processing Record 16 of Set 14 | imeni poliny osipenko
# Processing Record 17 of Set 14 | great falls
# Processing Record 18 of Set 14 | turtkul
# City not found. Skipping...
# Processing Record 19 of Set 14 | qinzhou
# Processing Record 20 of Set 14 | jalu
# Processing Record 21 of Set 14 | syracuse
# Processing Record 22 of Set 14 | kangaatsiaq
# Processing Record 23 of Set 14 | jumla
# Processing Record 24 of Set 14 | santo antonio do ica
# Processing Record 25 of Set 14 | wanning
# Processing Record 26 of Set 14 | muli
# Processing Record 27 of Set 14 | garden city
# Processing Record 28 of Set 14 | inhambane
# Processing Record 29 of Set 14 | salta
# Processing Record 30 of Set 14 | carupano
# Processing Record 31 of Set 14 | tazovskiy
# Processing Record 32 of Set 14 | hamilton
# Processing Record 33 of Set 14 | batagay
# Processing Record 34 of Set 14 | muroto
# Processing Record 35 of Set 14 | yingzhong
# City not found. Skipping...
# Processing Record 36 of Set 14 | beboto
# Processing Record 37 of Set 14 | ginir
# Processing Record 38 of Set 14 | chifeng
# Processing Record 39 of Set 14 | nizhniy odes
# Processing Record 40 of Set 14 | westport
# Processing Record 41 of Set 14 | golyshmanovo
# Processing Record 42 of Set 14 | batticaloa
# Processing Record 43 of Set 14 | moroni
# Processing Record 44 of Set 14 | ryotsu
# Processing Record 45 of Set 14 | lata
# Processing Record 46 of Set 14 | koutiala
# Processing Record 47 of Set 14 | viesca
# Processing Record 48 of Set 14 | santa cruz
# Processing Record 49 of Set 14 | terre haute
# Processing Record 50 of Set 14 | fallon
# Processing Record 1 of Set 15 | ekhabi
# Processing Record 2 of Set 15 | piacabucu
# Processing Record 3 of Set 15 | ahuimanu
# Processing Record 4 of Set 15 | talitsa
# Processing Record 5 of Set 15 | meadow lake
# Processing Record 6 of Set 15 | pusad
# Processing Record 7 of Set 15 | faizpur
# Processing Record 8 of Set 15 | palana
# Processing Record 9 of Set 15 | paraiso
# Processing Record 10 of Set 15 | sofiysk
# City not found. Skipping...
# Processing Record 11 of Set 15 | matara
# Processing Record 12 of Set 15 | dabat
# Processing Record 13 of Set 15 | panzhihua
# Processing Record 14 of Set 15 | kolokani
# Processing Record 15 of Set 15 | porto walter
# Processing Record 16 of Set 15 | meulaboh
# Processing Record 17 of Set 15 | shitanjing
# Processing Record 18 of Set 15 | lagos
# Processing Record 19 of Set 15 | lazaro cardenas
# Processing Record 20 of Set 15 | posse
# Processing Record 21 of Set 15 | maues
# Processing Record 22 of Set 15 | yichang
# Processing Record 23 of Set 15 | gifhorn
# Processing Record 24 of Set 15 | obregon
# Processing Record 25 of Set 15 | warrington
# Processing Record 26 of Set 15 | malmo
# Processing Record 27 of Set 15 | forio
# Processing Record 28 of Set 15 | baghdad
# Processing Record 29 of Set 15 | muros
# Processing Record 30 of Set 15 | disna
# Processing Record 31 of Set 15 | keita
# Processing Record 32 of Set 15 | ormara
# Processing Record 33 of Set 15 | agropoli
# Processing Record 34 of Set 15 | quelimane
# Processing Record 35 of Set 15 | alta floresta
# Processing Record 36 of Set 15 | katherine
# Processing Record 37 of Set 15 | vanavara
# Processing Record 38 of Set 15 | prince rupert
# Processing Record 39 of Set 15 | okhotsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Atuona  -9.8000 -139.0333     77.07        80          31
# 1         Honiara  -9.4333  159.9500     83.91        71           1
# 2         Agutaya  11.1480  120.9417     83.68        78         100
# 3         Kavieng  -2.5744  150.7967     83.64        73          44
# 4        Hermanus -34.4187   19.2345     53.91        83          11
# 5     Tuktoyaktuk  69.4541 -133.0374     60.80        88          90
# 6  Port Macquarie -31.4333  152.9167     49.89        41           0
# 7         Andenes  69.3143   16.1194     49.98        87          83
# 8         Itarema  -2.9248  -39.9167     78.73        84          76
# 9    Puerto Ayora  -0.7393  -90.3518     75.16        81          44
#
#    Wind Speed Current Description Country
# 0       14.16    scattered clouds      PF
# 1        5.10           clear sky      SB
# 2       16.11       moderate rain      PH
# 3        7.25          light rain      PG
# 4        6.82          few clouds      ZA
# 5       10.36     overcast clouds      CA
# 6        4.68           clear sky      AU
# 7       23.02       broken clouds      NO
# 8       12.62       broken clouds      BR
# 9        9.19    scattered clouds      EC

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Atuona      PF  -9.8000 -139.0333     77.07        80          31
# 1         Honiara      SB  -9.4333  159.9500     83.91        71           1
# 2         Agutaya      PH  11.1480  120.9417     83.68        78         100
# 3         Kavieng      PG  -2.5744  150.7967     83.64        73          44
# 4        Hermanus      ZA -34.4187   19.2345     53.91        83          11
# 5     Tuktoyaktuk      CA  69.4541 -133.0374     60.80        88          90
# 6  Port Macquarie      AU -31.4333  152.9167     49.89        41           0
# 7         Andenes      NO  69.3143   16.1194     49.98        87          83
# 8         Itarema      BR  -2.9248  -39.9167     78.73        84          76
# 9    Puerto Ayora      EC  -0.7393  -90.3518     75.16        81          44
#
#    Wind Speed Current Description
# 0       14.16    scattered clouds
# 1        5.10           clear sky
# 2       16.11       moderate rain
# 3        7.25          light rain
# 4        6.82          few clouds
# 5       10.36     overcast clouds
# 6        4.68           clear sky
# 7       23.02       broken clouds
# 8       12.62       broken clouds
# 9        9.19    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
